# %% [markdown]
# <a href="https://colab.research.google.com/github/gnitnaw/Programs/blob/master/Chapter3/MCsim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.7.11

# %% [markdown]
# # Example 3.5
# ## Import modules

# %%
import numpy as np
import matplotlib.pyplot as plt
print(np.__version__)
# Out:
# 1.19.5

# %% [markdown]
# ## Set random seed

# %%
np.random.seed(120)

# %% [markdown]
# ## Original Program

# %%
n = 101
P = np.array([[0, 0.2, 0.5, 0.3],
                [0.5, 0, 0.5, 0],
                [0.3, 0.7, 0, 0],
                [0.1, 0, 0, 0.9]])
x = np.array(np.ones(n, dtype=int))
x[0] = 0
for t in range(0,n-1):
    x[t+1] = np.min(np.where(np.cumsum(P[x[t],:])> np.random.rand()))  
x = x + 1  #add 1 to all elements of the vector x
plt.plot(np.array(range(0,n)),x, 'o')
plt.plot(np.array(range(0,n)),x, '--')
plt.show()
